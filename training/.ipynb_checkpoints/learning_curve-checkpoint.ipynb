# %%
import numpy as np 
#f = open('MobileNet_0.0003.log')
#f = open('MobileNet_0.0003.log')
#f = open('log/VggNet_0.000040.log')
#f = open('MobileNet_0.00004.log')
#f = open('log/MobileNet_201707062102.txt')
#f = open('log/MobileNet_201707101737.txt')
#f = open('MobileNet_new_0.00004_60000.log')
#f = open('MobileNet_0.00004_0713.log')
#f = open('MobileNet_0.00004_0713_perterb26.log')
#f = open('MobileNet_368.log')
#f = open('log/MobileNet_201707131101.txt')
f = open('Resnet.log')
log = f.read()
import re
p = re.compile(r'loss = ([0-9]+([.][0-9]+){0,1})')
re_r = p.findall(log)
import matplotlib
# %matplotlib inline
import pylab as plt
loss_arr = [float(tup[0]) for tup in re_r][50 / 5 : 80000 / 5]
loss_list = []
step = 50
for i in range(len(loss_arr)/step):
    loss_list.append(np.mean(loss_arr[step*i: step*(i+1)]))
pic = plt.plot(range(0, 5*len(loss_arr), 5), loss_arr)
pic = plt.plot(range(0, 5*len(loss_list)*step, 5*step), loss_list, 'ro')
plt.grid(True, color = "r")  
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
import numpy as np
np.asarray(loss_arr[-50:]).astype(float).mean()
# Out:
# 277.73594000000003
